# %% [markdown]
# # Tab : indent

# %%
    import cv2

# %% [markdown]
# # Ctrl-]: indent

# %%
    image = cv2.imread("C:/Users/parag/Desktop/2.jfif")

# %% [markdown]
# # Ctrl-[: dedent

# %%
type(image)
# Out:
# numpy.ndarray

# %% [markdown]
# # Ctrl-A: select all

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# # Ctrl-Z: undo

# %%
from skimage import io

# %% [markdown]
# # Ctrl-/ comment

# %%
car2 = io.imread("C:/Users/parag/Desktop/2.jfif")

# %% [markdown]
# # Ctrl-D: delete whole line

# %%
io.imshow(car2)
io.show()

# %% [markdown]
# # Ctrl-U: undo selection

# %%
import imutils
image = cv2.imread('C:/Users/PARAG/Desktop/download.jfif')
image = imutils.resize(image,width=500)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# # Insert: toggle overwrite flag

# %%
gray = cv2.cvt2Color(image,cv2.COLOR_RGB2GRAY)
plt.imshow(gray)

# %% [markdown]
# # Ctrl-Home: go to cell start

# %%
gray = cv2.bilateralFilter(gray,11,17,17)
plt.imshow(gray)

# %% [markdown]
# # Ctrl-End: go to cell end

# %%
edged = cv2.Canny(gray,170,200)
plt.imshow(edged)

# %% [markdown]
# # Ctrl-Left: go one word left

# %%
cnts, new = cv2.findContours(edged.copy(),cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)

# %% [markdown]
# # Ctrl-Right: go one word right

# %%
img1 = image.copy()
cv2.drawContours(img1,cnts,-1,(0,255,0),3)
plt.imshow(img1)

# %% [markdown]
# # Ctrl-Backspace: delete word before

# %%
cnts=sorted(cnts,key=cv2.contourArea,reverse=True)[:30]
NumberPlateCnt=None 
img2=image.copy()
cv2.drawContours(img2,cnts,-1,(0,255,0),3)
plt.imshow(img2)

# %% [markdown]
# # Ctrl-Delete: delete word after

# %%
idx=1
for c in cnts:
    peri = cv2.arcLength(c,True)
    approx = cv2.approxPolyDP(c,0.02*peri,True)
    if len(approx) == 4 : 
        NumberPlateCnt=approx 
        x , y, w, h = cv2.boundingRect(c) 
        new_img = gray[y:y+h,x:x+w] 
        cv2.imwrite('C:/Users/PARAG/Desktop/' + str(idx) + '.png',new_img) 
        break

cv2.drawContours(image,[NumberPlateCnt],-1,(0,255,0),3)
plt.imshow(image)
