# %% [markdown]
# # Reading and displaying Image using opencv

# %%
import cv2

# %%
car1 = cv2.imread("C:/Users/parag/Desktop/1.png")

# %%
car1 = cv2.cvtColor(car1,cv2.COLOR_BGR2RGB)

# %%
cv2.imshow("Car image",car1)
cv2.waitKey(1)
# Out:
# -1

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(car1)

# %%
from skimage import io

# %%
car2 = io.imread("C:/Users/parag/Desktop/2.jfif")

# %%
io.imshow(car2)
io.show()
